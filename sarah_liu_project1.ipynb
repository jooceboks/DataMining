# %% [markdown]
# # Project 1 -- Sarah Liu

# %%
# import pandas library 
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
myDF.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %% [markdown]
# ## Q1

# %%
# created a df in Pandas using read_csv func and read the data from the 
# olympic athletes dataset into this df called Df2
Df2 = pd.read_csv('/anvil/projects/tdm/data/olympics/athlete_events.csv')

# display first 12 rows of data (0-11)
Df2.head(12)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %% [markdown]
# ## Q2

# %%
# display num of rows and cols w .shape func
Df2.shape
# Out:
# (271116, 15)

# %%
# display last 5 rows - show 271116 rows exist
Df2.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
# dispaly and filter to find athletes from Team = Jamaica, Sport = Bobsleigh, Games = Winter 1988
Df2[(Df2['Games'] == '1988 Winter') & (Df2['Team'] == 'Jamaica') & (Df2['Sport'] == 'Bobsleigh')]
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 91083    46160             Devon Desmond Harris   M  23.0   178.0    97.0
# 229854  115398  Nelson Christian "Chris" Stokes   M  24.0   189.0    90.0
# 229860  115400           Dudley Clifford Stokes   M  25.0   183.0    89.0
# 229861  115400           Dudley Clifford Stokes   M  25.0   183.0    89.0
# 259694  130007                    Michael White   M  23.0   182.0   107.0
# 259695  130007                    Michael White   M  23.0   182.0   107.0
#
#            Team  NOC        Games  Year  Season     City      Sport  \
# 91083   Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229854  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229860  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229861  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 259694  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# ...

# %% [markdown]
# # Q3

# %%
# use value_counts func to count number of athletes in each team 
# use head() to display top 5 countries with the most athletes
# store in counts 
# use display() func to display values stored in counts

counts = Df2['Team'].value_counts().head()
display(counts)
# Out:
# Team
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Name: count, dtype: int64

# %%
# import matplotlib.pyplot library 
import matplotlib.pyplot as plt

# plot bar graph x axis = Team, y axis = # of athletes on team 
plt.bar(counts.index, counts)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Q4

# %%
# load and read restaurant vendor dataset to Df3 
# display head to check if properly loaded
Df3 = pd.read_csv('/anvil/projects/tdm/data/restaurant/vendors.csv')
Df3.head()
# Out:
#    id  authentication_id  latitude  longitude vendor_category_en  \
# 0   4           118597.0 -0.588596   0.754434        Restaurants
# 1  13           118608.0 -0.471654   0.744470        Restaurants
# 2  20           118616.0 -0.407527   0.643681        Restaurants
# 3  23           118619.0 -0.585385   0.753811        Restaurants
# 4  28           118624.0  0.480602   0.552850        Restaurants
#
#    vendor_category_id  delivery_charge  serving_distance  is_open  \
# 0                 2.0              0.0               6.0      1.0
# 1                 2.0              0.7               5.0      1.0
# 2                 2.0              0.0               8.0      1.0
# 3                 2.0              0.0               5.0      1.0
# 4                 2.0              0.7              15.0      1.0
#
#        OpeningTime  ... open_close_flags                 vendor_tag  \
# 0  11:00AM-11:30PM  ...              1.0  2,4,5,8,91,22,12,24,16,23
# ...

# %%
# use value_counts func to count how many times each vendor in 'vendor_category_en' appears 
# in dataset. Store in VendorCount and display using disaply() func
VendorCount = Df3['vendor_category_en'].value_counts()
display(VendorCount)
# Out:
# vendor_category_en
# Restaurants       88
# Sweets & Bakes    12
# Name: count, dtype: int64

# %% [markdown]
# # Q5

# %%
# display simple bar graph of both vendors and number each Vendor type appears using plt.bar 
plt.bar(VendorCount.index, VendorCount)
# Out:
# <BarContainer object of 2 artists>
